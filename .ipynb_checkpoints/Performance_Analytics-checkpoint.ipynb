# %%
# Fund Performance Analytics

## Key Findings

1. Daily returns were calculated for all mutual fund schemes.

2. CAGR analysis identified long term performing funds.

3. Sharpe ratio ranked funds based on risk adjusted returns.

4. Sortino ratio measured downside risk performance.

5. Alpha and Beta showed fund sensitivity against benchmark.

6. Maximum drawdown identified downside periods.

7. Composite fund scorecard ranked the best performing schemes.

8. Top funds were compared with benchmark performance.
